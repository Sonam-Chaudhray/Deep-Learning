# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# # Read CSV

# %%
data = pd.read_csv("data/heart_failure_clinical_records_dataset.csv")

# %% [markdown]
# # Split

# %%
# Split features (X) and target variable (y)
X = data.drop("DEATH_EVENT", axis=1)
y = data["DEATH_EVENT"]

# %% [markdown]
# # Perform Feature Scaling

# %%
# Perform feature scaling
scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)

# Step 3: Train-Test Split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=11)

# %% [markdown]
# # Build Model

# %%
model = Sequential()
model.add(Dense(29, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(11, activation='relu'))
model.add(Dense(5, activation='tanh'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 29)                377
#
#  dense_1 (Dense)             (None, 11)                330
#
#  dense_2 (Dense)             (None, 5)                 60
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 773 (3.02 KB)
# Trainable params: 773 (3.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# w1 w2 w3 w4 w5 + b

# %% [markdown]
# # Compile

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# log_dir = "logs/classification_tf/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = "logs/classification_tf/"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# # Train

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=2, validation_split=0.1,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/100
# 108/108 [==============================] - 2s 11ms/step - loss: 0.6281 - accuracy: 0.6837 - val_loss: 0.4965 - val_accuracy: 0.8750
# Epoch 2/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5634 - accuracy: 0.7349 - val_loss: 0.4334 - val_accuracy: 0.8750
# Epoch 3/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5171 - accuracy: 0.7628 - val_loss: 0.4114 - val_accuracy: 0.8750
# Epoch 4/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4803 - accuracy: 0.8047 - val_loss: 0.3880 - val_accuracy: 0.8750
# Epoch 5/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4514 - accuracy: 0.8140 - val_loss: 0.3760 - val_accuracy: 0.8750
# Epoch 6/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.4276 - accuracy: 0.8233 - val_loss: 0.3496 - val_accuracy: 0.8750
# Epoch 7/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4114 - accuracy: 0.8279 - val_loss: 0.3444 - val_accuracy: 0.8750
# Epoch 8/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.3974 - accuracy: 0.8186 - val_loss: 0.3385 - val_accuracy: 0.8750
# Epoch 9/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.3858 - accuracy: 0.8419 - val_loss: 0.3282 - val_accuracy: 0.8750
# Epoch 10/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.3732 - accuracy: 0.8465 - val_loss: 0.3313 - val_accuracy: 0.8750
# Epoch 11/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3661 - accuracy: 0.8465 - val_loss: 0.3218 - val_accuracy: 0.8750
# Epoch 12/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.3565 - accuracy: 0.8558 - val_loss: 0.3391 - val_accuracy: 0.8750
# Epoch 13/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3480 - accuracy: 0.8651 - val_loss: 0.3159 - val_accuracy: 0.8750
# Epoch 14/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3383 - accuracy: 0.8698 - val_loss: 0.3403 - val_accuracy: 0.8333
# Epoch 15/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3287 - accuracy: 0.8698 - val_loss: 0.3295 - val_accuracy: 0.8750
# Epoch 16/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3233 - accuracy: 0.8884 - val_loss: 0.3380 - val_accuracy: 0.8333
# Epoch 17/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3157 - accuracy: 0.8791 - val_loss: 0.3415 - val_accuracy: 0.8333
# Epoch 18/100
# 108/108 [==============================] - 1s 7ms/step - loss: 0.3037 - accuracy: 0.8837 - val_loss: 0.3315 - val_accuracy: 0.8333
# Epoch 19/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2977 - accuracy: 0.8977 - val_loss: 0.3853 - val_accuracy: 0.8333
# Epoch 20/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.2921 - accuracy: 0.8837 - val_loss: 0.4088 - val_accuracy: 0.8333
# Epoch 21/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.2824 - accuracy: 0.9116 - val_loss: 0.4025 - val_accuracy: 0.8333
# Epoch 22/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.2738 - accuracy: 0.9023 - val_loss: 0.4329 - val_accuracy: 0.8333
# Epoch 23/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.2639 - accuracy: 0.9116 - val_loss: 0.4514 - val_accuracy: 0.8333
# Epoch 24/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.2585 - accuracy: 0.9070 - val_loss: 0.4409 - val_accuracy: 0.8333
# Epoch 25/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.2474 - accuracy: 0.9163 - val_loss: 0.4404 - val_accuracy: 0.8333
# Epoch 26/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.2399 - accuracy: 0.9209 - val_loss: 0.4614 - val_accuracy: 0.7917
# Epoch 27/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.2329 - accuracy: 0.9256 - val_loss: 0.4778 - val_accuracy: 0.8333
# Epoch 28/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.2243 - accuracy: 0.9256 - val_loss: 0.5134 - val_accuracy: 0.8333
# Epoch 29/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.2228 - accuracy: 0.9256 - val_loss: 0.5005 - val_accuracy: 0.7917
# Epoch 30/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.2170 - accuracy: 0.9256 - val_loss: 0.4858 - val_accuracy: 0.8333
# Epoch 31/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.2063 - accuracy: 0.9256 - val_loss: 0.4667 - val_accuracy: 0.8333
# Epoch 32/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.2001 - accuracy: 0.9256 - val_loss: 0.5139 - val_accuracy: 0.8333
# Epoch 33/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1915 - accuracy: 0.9302 - val_loss: 0.4834 - val_accuracy: 0.8333
# Epoch 34/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1896 - accuracy: 0.9442 - val_loss: 0.5217 - val_accuracy: 0.8333
# Epoch 35/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1792 - accuracy: 0.9535 - val_loss: 0.5654 - val_accuracy: 0.8333
# Epoch 36/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1727 - accuracy: 0.9395 - val_loss: 0.5297 - val_accuracy: 0.8333
# Epoch 37/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1786 - accuracy: 0.9442 - val_loss: 0.4806 - val_accuracy: 0.8333
# Epoch 38/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1654 - accuracy: 0.9395 - val_loss: 0.4598 - val_accuracy: 0.8333
# Epoch 39/100
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1638 - accuracy: 0.9395 - val_loss: 0.5048 - val_accuracy: 0.8333
# Epoch 40/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1484 - accuracy: 0.9535 - val_loss: 0.4454 - val_accuracy: 0.8333
# Epoch 41/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1530 - accuracy: 0.9395 - val_loss: 0.4828 - val_accuracy: 0.8333
# Epoch 42/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1480 - accuracy: 0.9628 - val_loss: 0.4928 - val_accuracy: 0.8333
# Epoch 43/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1323 - accuracy: 0.9581 - val_loss: 0.5210 - val_accuracy: 0.8333
# Epoch 44/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1367 - accuracy: 0.9535 - val_loss: 0.4983 - val_accuracy: 0.8333
# Epoch 45/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1278 - accuracy: 0.9488 - val_loss: 0.4805 - val_accuracy: 0.8333
# Epoch 46/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1309 - accuracy: 0.9628 - val_loss: 0.4927 - val_accuracy: 0.8333
# Epoch 47/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.1166 - accuracy: 0.9674 - val_loss: 0.4926 - val_accuracy: 0.8333
# Epoch 48/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1141 - accuracy: 0.9628 - val_loss: 0.4677 - val_accuracy: 0.8333
# Epoch 49/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.1183 - accuracy: 0.9581 - val_loss: 0.4890 - val_accuracy: 0.8333
# Epoch 50/100
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1203 - accuracy: 0.9628 - val_loss: 0.4930 - val_accuracy: 0.8333
# Epoch 51/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.1076 - accuracy: 0.9674 - val_loss: 0.4619 - val_accuracy: 0.8333
# Epoch 52/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9721 - val_loss: 0.4351 - val_accuracy: 0.8750
# Epoch 53/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1075 - accuracy: 0.9628 - val_loss: 0.4652 - val_accuracy: 0.8333
# Epoch 54/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.1029 - accuracy: 0.9721 - val_loss: 0.4644 - val_accuracy: 0.8750
# Epoch 55/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0886 - accuracy: 0.9767 - val_loss: 0.4865 - val_accuracy: 0.8333
# Epoch 56/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0834 - accuracy: 0.9767 - val_loss: 0.4618 - val_accuracy: 0.8750
# Epoch 57/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.9674 - val_loss: 0.4851 - val_accuracy: 0.8750
# Epoch 58/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0804 - accuracy: 0.9767 - val_loss: 0.4567 - val_accuracy: 0.8750
# Epoch 59/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0738 - accuracy: 0.9814 - val_loss: 0.4753 - val_accuracy: 0.8750
# Epoch 60/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0867 - accuracy: 0.9767 - val_loss: 0.4725 - val_accuracy: 0.8750
# Epoch 61/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0716 - accuracy: 0.9814 - val_loss: 0.4970 - val_accuracy: 0.8333
# Epoch 62/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0749 - accuracy: 0.9860 - val_loss: 0.5378 - val_accuracy: 0.8333
# Epoch 63/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0692 - accuracy: 0.9907 - val_loss: 0.4923 - val_accuracy: 0.8750
# Epoch 64/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9860 - val_loss: 0.5260 - val_accuracy: 0.8333
# Epoch 65/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0535 - accuracy: 0.9907 - val_loss: 0.5341 - val_accuracy: 0.8333
# Epoch 66/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0494 - accuracy: 0.9907 - val_loss: 0.4957 - val_accuracy: 0.8750
# Epoch 67/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0677 - accuracy: 0.9767 - val_loss: 0.4792 - val_accuracy: 0.8750
# Epoch 68/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0438 - accuracy: 0.9907 - val_loss: 0.5103 - val_accuracy: 0.8750
# Epoch 69/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0393 - accuracy: 0.9953 - val_loss: 0.5377 - val_accuracy: 0.8333
# Epoch 70/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 0.9860 - val_loss: 0.5446 - val_accuracy: 0.8333
# Epoch 71/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0410 - accuracy: 0.9953 - val_loss: 0.5650 - val_accuracy: 0.8333
# Epoch 72/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.5320 - val_accuracy: 0.8750
# Epoch 73/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0354 - accuracy: 0.9953 - val_loss: 0.5437 - val_accuracy: 0.8333
# Epoch 74/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.5549 - val_accuracy: 0.8750
# Epoch 75/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0355 - accuracy: 0.9907 - val_loss: 0.5404 - val_accuracy: 0.8750
# Epoch 76/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0593 - accuracy: 0.9907 - val_loss: 0.5315 - val_accuracy: 0.8750
# Epoch 77/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0327 - accuracy: 0.9953 - val_loss: 0.5217 - val_accuracy: 0.8750
# Epoch 78/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.5621 - val_accuracy: 0.8750
# Epoch 79/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.5551 - val_accuracy: 0.8750
# Epoch 80/100
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.5667 - val_accuracy: 0.8750
# Epoch 81/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.5708 - val_accuracy: 0.8750
# Epoch 82/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.5722 - val_accuracy: 0.8750
# Epoch 83/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.9953 - val_loss: 0.5865 - val_accuracy: 0.8750
# Epoch 84/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.5895 - val_accuracy: 0.8750
# Epoch 85/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.5817 - val_accuracy: 0.8750
# Epoch 86/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.5798 - val_accuracy: 0.8750
# Epoch 87/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.5784 - val_accuracy: 0.8750
# Epoch 88/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.5801 - val_accuracy: 0.8750
# Epoch 89/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.5930 - val_accuracy: 0.8750
# Epoch 90/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.5882 - val_accuracy: 0.8750
# Epoch 91/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.5972 - val_accuracy: 0.8750
# Epoch 92/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.5960 - val_accuracy: 0.8750
# Epoch 93/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.6098 - val_accuracy: 0.8750
# Epoch 94/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.5812 - val_accuracy: 0.8750
# Epoch 95/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.5993 - val_accuracy: 0.8750
# Epoch 96/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.6020 - val_accuracy: 0.8750
# Epoch 97/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.8750
# Epoch 98/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.6141 - val_accuracy: 0.8750
# Epoch 99/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.6193 - val_accuracy: 0.8750
# Epoch 100/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.6176 - val_accuracy: 0.8750

# %% [markdown]
# # Evaluate

# %%
y_pred = model.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
y_pred = (y_pred > 0.5).astype(int)

# %% [markdown]
# # Metrics

# %%
from sklearn.metrics import accuracy_score,recall_score, precision_score, f1_score,classification_report

# %%
print("Model's acuracy :",accuracy_score(y_pred,y_test))
print("Recall-Score :",recall_score(y_pred,y_test))
print("Precision-Score :",precision_score(y_pred,y_test))
print("F1-Score :",f1_score(y_pred,y_test))
# Out:
# Model's acuracy : 0.7666666666666667
# Recall-Score : 0.5555555555555556
# Precision-Score : 0.8823529411764706
# F1-Score : 0.6818181818181819

# %% [markdown]
# # Classification Report

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.94      0.82        33
#            1       0.88      0.56      0.68        27
#
#     accuracy                           0.77        60
#    macro avg       0.80      0.75      0.75        60
# weighted avg       0.79      0.77      0.76        60

# %% [markdown]
# # Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
# Compute confusion matrix
cm = confusion_matrix(y_pred , y_test)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Visualize

# %%
from tensorflow.keras.models import Model

# %%
def get_activations(model, layer_name, X):
    layer = model.get_layer(name=layer_name)
    activation_model = Model(inputs=model.input, outputs=layer.output)
    activations = activation_model.predict(X, verbose=False)
    print(activations)
    return activations

# %%
def plot_activations(layer_name, activations):
    print(f"Layer: {layer_name}")
    print(f"Activation Shape: {activations.shape}")

    if len(activations.shape) == 2:
        # 2D activations (Dense layers)
        plt.figure(figsize=(10, 5))
        plt.bar(range(activations.shape[1]), activations[0], color='skyblue')
        plt.title(f'Activations of {layer_name}')
        plt.xlabel('Neurons')
        plt.ylabel('Activation')
        plt.grid(True)
        plt.show()
    
    elif len(activations.shape) == 3:
        # 3D activations (Convolutional layers)
        num_channels = activations.shape[-1]
        for i in range(num_channels):
            plt.figure(figsize=(10, 5))
            plt.imshow(activations[0, :, :, i], aspect='auto', cmap='viridis')
            plt.colorbar()
            plt.title(f'Activations of {layer_name} - Channel {i}')
            plt.xlabel('Width')
            plt.ylabel('Height')
            plt.show()

    elif len(activations.shape) == 4:
        # 4D activations (Batches of 3D data, e.g., convolutional layers)
        num_samples = activations.shape[1]
        for i in range(num_samples):
            plt.figure(figsize=(10, 5))
            plt.imshow(activations[0, i, :, :], aspect='auto', cmap='viridis')
            plt.colorbar()
            plt.title(f'Activations of {layer_name} - Sample {i}')
            plt.xlabel('Width')
            plt.ylabel('Height')
            plt.show()

    else:
        print(f"Activation shape {activations.shape} not supported for visualization")

# %%
layer_names = [layer.name for layer in model.layers]

X_sample = x_train[11]
X_sample = np.expand_dims(X_sample, axis=0)  

for layer_name in layer_names:
    activations = get_activations(model, layer_name, X_sample)
    plot_activations(layer_name, activations)
# Out:
# [[0.5125824  0.         1.8544557  0.         0.         0.
#   0.         0.         1.1063318  0.         0.         0.5315499
#   0.         0.7495696  0.10376801 0.         0.         0.
#   0.         0.65428424 1.7785026  0.51811713 0.         0.
#   0.         0.03831735 1.1163151  0.41461843 0.6417757 ]]
# Layer: dense
# Activation Shape: (1, 29)
# [[1.0279359 1.3189399 1.0883461 1.1816354 1.4111993 0.        0.
#   0.        0.        0.7540784 1.084742 ]]
# Layer: dense_1
# Activation Shape: (1, 11)
# [[ 0.99489695 -0.9720284  -0.9971597   0.54261845 -0.9192694 ]]
# Layer: dense_2
# Activation Shape: (1, 5)
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000166BFE863A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[0.00076404]]
# Layer: dense_3
# Activation Shape: (1, 1)

# %%
layer_names = [layer.name for layer in model.layers]

X_sample = x_train[11]
X_sample = np.expand_dims(X_sample, axis=0)  

for layer_name in layer_names:
    activations = get_activations(model, layer_name, X_sample)
    plot_activations(layer_name, activations)
# Out:
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000166BDC8EA60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[0.5125824  0.         1.8544557  0.         0.         0.
#   0.         0.         1.1063318  0.         0.         0.5315499
#   0.         0.7495696  0.10376801 0.         0.         0.
#   0.         0.65428424 1.7785026  0.51811713 0.         0.
#   0.         0.03831735 1.1163151  0.41461843 0.6417757 ]]
# Layer: dense
# Activation Shape: (1, 29)
# [[1.0279359 1.3189399 1.0883461 1.1816354 1.4111993 0.        0.
#   0.        0.        0.7540784 1.084742 ]]
# Layer: dense_1
# Activation Shape: (1, 11)
# [[ 0.99489695 -0.9720284  -0.9971597   0.54261845 -0.9192694 ]]
# Layer: dense_2
# Activation Shape: (1, 5)
# [[0.00076404]]
# Layer: dense_3
# Activation Shape: (1, 1)
