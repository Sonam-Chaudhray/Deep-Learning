# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import models

# %%
d_model = tf.keras.models.load_model('models/discriminator.h5')
g_model = tf.keras.models.load_model('models/generator.h5')
cgan = tf.keras.models.load_model('models/cgan.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # Compile

# %%
d_model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')
cgan.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # Generate

# %%
def generate_image(number):
    # Define the latent dimension (same as used during training)
    latent_dim = 100  # example latent dimension

    # Generate a random latent vector
    z = np.random.normal(0, 1, (1, latent_dim))

    # Specify the label you want to generate (e.g., label 3)
    label = np.array([number])

    # Generate the image
    generated_image = g_model.predict([z, label], verbose=False)

    # If the output is in range [-1, 1] (due to tanh activation), rescale it to [0, 1]
    generated_image = (generated_image + 1) / 2.0

    plt.imshow(generated_image[0, :, :, 0], cmap='gray')
    plt.axis('off')
    plt.show()

    score = d_model.predict([generated_image, label], verbose=False)
    print(f'Discriminator score: {score[0][0]}')

    print("-------------------------------------------------------")

# %%
for i in range(10):
    print(f"Generating number {i}")
    generate_image(i)
# Out:
# Generating number 0
# Discriminator score: 0.0005156825645826757
# -------------------------------------------------------
# Generating number 1
# Discriminator score: 0.0018809831235557795
# -------------------------------------------------------
# Generating number 2
# Discriminator score: 0.00012495278497226536
# -------------------------------------------------------
# Generating number 3
# Discriminator score: 0.03254270926117897
# -------------------------------------------------------
# Generating number 4
# Discriminator score: 0.00031422398751601577
# -------------------------------------------------------
# Generating number 5
# Discriminator score: 0.000535115017555654
# -------------------------------------------------------
# Generating number 6
# Discriminator score: 0.0030115717090666294
# -------------------------------------------------------
# Generating number 7
# Discriminator score: 0.006277307402342558
# -------------------------------------------------------
# Generating number 8
# Discriminator score: 0.0005439551896415651
# -------------------------------------------------------
# Generating number 9
# Discriminator score: 0.014140583574771881
# -------------------------------------------------------

# %%
for i in range(10):
    print(f"Generating number {i}")
    generate_image(i)
# Out:
# Generating number 0
# Discriminator score: 0.025693757459521294
# -------------------------------------------------------
# Generating number 1
# Discriminator score: 0.0036837870720773935
# -------------------------------------------------------
# Generating number 2
# Discriminator score: 0.0003947883960790932
# -------------------------------------------------------
# Generating number 3
# Discriminator score: 0.005593867506831884
# -------------------------------------------------------
# Generating number 4
# Discriminator score: 0.0005805951077491045
# -------------------------------------------------------
# Generating number 5
# Discriminator score: 0.00019748795602936298
# -------------------------------------------------------
# Generating number 6
# Discriminator score: 0.004364992491900921
# -------------------------------------------------------
# Generating number 7
# Discriminator score: 0.0018403619760647416
# -------------------------------------------------------
# Generating number 8
# Discriminator score: 0.0004560808592941612
# -------------------------------------------------------
# Generating number 9
# Discriminator score: 0.0010038093896582723
# -------------------------------------------------------
